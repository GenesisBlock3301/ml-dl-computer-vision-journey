# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
img = cv2.imread("./img2.png")  # shape: (H, W, 3)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  # optional, work with single channel

# Define a simple kernel (3x3 edge detection)
kernel = np.array([[ -1, -1, -1],
                   [ -1,  8, -1],
                   [ -1, -1, -1]], dtype=np.float32)

# Apply convolution
feature_map = cv2.filter2D(img_gray, -1, kernel)


# Define a simple kernel (3x3 edge detection)
# kernel2 = np.array([[ -1, -1, -1],
#                    [ -1,  8, -1],
#                    [ -1, -1, -1]], dtype=np.float32)
#
# feature_map2 = cv2.filter2D(feature_map, -1, kernel2)


def max_pooling(feature_map, pool_size=2, stride=2):
    h, w = feature_map.shape
    new_h = h // stride
    new_w = w // stride
    pooled = np.zeros((new_h, new_w), dtype=feature_map.dtype)

    for i in range(0, h, stride):
        for j in range(0, w, stride):
            window = feature_map[i:i+pool_size, j:j+pool_size]
            pooled[i//stride, j//stride] = np.max(window)

    return pooled

# Apply max pooling
pooled_map = max_pooling(feature_map, pool_size=2, stride=2)
print("Original shape:", feature_map.shape)
print("Pooled shape:", pooled_map.shape)



# Visualize
plt.figure(figsize=(10,5))
plt.subplot(1,4,1)
plt.title("Original")
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.subplot(1,4,2)
plt.title("image_gray")
plt.imshow(img_gray, cmap='gray')
plt.axis('off')

plt.subplot(1,4,3)
plt.title("Feature map")
plt.imshow(feature_map, cmap='gray')
plt.axis('off')
plt.subplot(1,4,4)
plt.title("pooled_map")
plt.imshow(pooled_map, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 41
#      38     return pooled
#      40 # Apply max pooling
# ---> 41 pooled_map = max_pooling(feature_map, pool_size=2, stride=2)
#      42 print("Original shape:", feature_map.shape)
#      43 print("Pooled shape:", pooled_map.shape)
#
# Cell In[5], line 33, in max_pooling(feature_map, pool_size, stride)
#      30 new_w = w // stride
#      31 pooled = np.zeros((new_h, new_w), dtype=feature_map.dtype)
# ---> 33 for i in range(0, h, stride):
#      34     for j in range(0, w, stride):
#      35         window = feature_map[i:i+pool_size, j:j+pool_size]
#
# File /snap/pycharm-professional/512/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:888, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     885             stop = False
#     887 if plugin_stop:
# --> 888     stopped_on_plugin = plugin_manager.stop(main_debugger, frame, event, self._args, stop_info, arg, step_cmd)
#     889 elif stop:
#     890     if is_line:
#
# File /snap/pycharm-professional/512/plugins/python-ce/helpers/jupyter_debug/pydev_jupyter_plugin.py:171, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     169     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     170     if frame:
# --> 171         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     172         return True
#     173 return False
#
# File /snap/pycharm-professional/512/plugins/python-ce/helpers/pydev/pydevd.py:1196, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1193         from_this_thread.append(frame_id)
#    1195 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1196     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /snap/pycharm-professional/512/plugins/python-ce/helpers/pydev/pydevd.py:1211, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1208             self._call_mpl_hook()
#    1210         self.process_internal_commands()
# -> 1211         time.sleep(0.01)
#    1213 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1215 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Generate a random high-contrast image (simulate edges everywhere)
img = np.random.randint(0, 256, (256, 256), dtype=np.uint8)

# Apply edge detection kernel (simple Laplacian-like)
kernel = np.array([[-1, -1, -1],
                   [-1, 8, -1],
                   [-1, -1, -1]], dtype=np.float32)
feature_map = cv2.filter2D(img, -1, kernel)

# Define max pooling function
def max_pooling(feature_map, pool_size=2, stride=2):
    h, w = feature_map.shape
    new_h = h // stride
    new_w = w // stride
    pooled = np.zeros((new_h, new_w), dtype=feature_map.dtype)
    for i in range(0, h, stride):
        for j in range(0, w, stride):
            window = feature_map[i:i+pool_size, j:j+pool_size]
            pooled[i//stride, j//stride] = np.max(window)
    return pooled

# Apply max pooling
pooled_map = max_pooling(feature_map, pool_size=2, stride=2)

print("Original shape:", img.shape)
print("Feature map shape:", feature_map.shape)
print("Pooled shape:", pooled_map.shape)

# Visualize
plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
plt.title("Original random image")
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(1,3,2)
plt.title("Feature map (edges)")
plt.imshow(feature_map, cmap='gray')
plt.axis('off')

plt.subplot(1,3,3)
plt.title("Max pooled (2x2)")
plt.imshow(pooled_map, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# Original shape: (256, 256)
# Feature map shape: (256, 256)
# Pooled shape: (128, 128)
